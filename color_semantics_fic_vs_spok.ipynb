# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Loading-and-preparing-data" data-toc-modified-id="Loading-and-preparing-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Loading and preparing data</a></span><ul class="toc-item"><li><span><a href="#Loading-original-participant-data-(NZ)" data-toc-modified-id="Loading-original-participant-data-(NZ)-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Loading original participant data (NZ)</a></span><ul class="toc-item"><li><span><a href="#Melt-dataframe-to-long-format" data-toc-modified-id="Melt-dataframe-to-long-format-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Melt dataframe to long format</a></span></li></ul></li><li><span><a href="#Loading-replication-participant-data-(US)" data-toc-modified-id="Loading-replication-participant-data-(US)-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Loading replication participant data (US)</a></span></li><li><span><a href="#Retrieving-vectors-for-words-and-dimension-word-pairs" data-toc-modified-id="Retrieving-vectors-for-words-and-dimension-word-pairs-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Retrieving vectors for words and dimension word pairs</a></span></li></ul></li><li><span><a href="#Finding-color-semantic-associations-in-word-embeddings" data-toc-modified-id="Finding-color-semantic-associations-in-word-embeddings-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Finding color-semantic associations in word embeddings</a></span><ul class="toc-item"><li><span><a href="#Using-single-dimension-words" data-toc-modified-id="Using-single-dimension-words-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Using single dimension words</a></span></li><li><span><a href="#Using-dimension-axes-(word-pair-contrasts),-with-nearest-neighbor-(cosine)-method" data-toc-modified-id="Using-dimension-axes-(word-pair-contrasts),-with-nearest-neighbor-(cosine)-method-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Using dimension axes (word pair contrasts), with nearest neighbor (cosine) method</a></span></li></ul></li><li><span><a href="#Predicting-color-semantics-association-ratings-from-word-embeddings" data-toc-modified-id="Predicting-color-semantics-association-ratings-from-word-embeddings-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Predicting color semantics association ratings from word embeddings</a></span><ul class="toc-item"><li><span><a href="#Merging-data-and-predictors" data-toc-modified-id="Merging-data-and-predictors-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Merging data and predictors</a></span><ul class="toc-item"><li><span><a href="#Merge-data" data-toc-modified-id="Merge-data-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Merge data</a></span></li><li><span><a href="#Add-word-frequency-(Van-Paridon-&amp;-Thompson,-2020)" data-toc-modified-id="Add-word-frequency-(Van-Paridon-&amp;-Thompson,-2020)-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Add word frequency (Van Paridon &amp; Thompson, 2020)</a></span></li><li><span><a href="#Add-concreteness-(Brysbaert-et-al.,-2014)" data-toc-modified-id="Add-concreteness-(Brysbaert-et-al.,-2014)-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Add concreteness (Brysbaert et al., 2014)</a></span></li><li><span><a href="#Add-Small-World-of-Words-associations-(De-Deyne-et-al.,-2018)" data-toc-modified-id="Add-Small-World-of-Words-associations-(De-Deyne-et-al.,-2018)-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Add Small World of Words associations (De Deyne et al., 2018)</a></span></li><li><span><a href="#Add-cosine-distance-(Mikolov-et-al.,-2013)" data-toc-modified-id="Add-cosine-distance-(Mikolov-et-al.,-2013)-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Add cosine distance (Mikolov et al., 2013)</a></span></li><li><span><a href="#Standardize-predictors-and-plot-correlations" data-toc-modified-id="Standardize-predictors-and-plot-correlations-3.1.6"><span class="toc-item-num">3.1.6&nbsp;&nbsp;</span>Standardize predictors and plot correlations</a></span></li></ul></li><li><span><a href="#Predicting-color-semantics-in-original-data-(blind-vs.-sighted-in-NZ)" data-toc-modified-id="Predicting-color-semantics-in-original-data-(blind-vs.-sighted-in-NZ)-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Predicting color semantics in original data (blind vs. sighted in NZ)</a></span></li><li><span><a href="#Predicting-color-semantics-in-replication-data-(sighted-in-US)" data-toc-modified-id="Predicting-color-semantics-in-replication-data-(sighted-in-US)-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Predicting color semantics in replication data (sighted in US)</a></span></li><li><span><a href="#Differences-in-color-semantics-between-original-and-replication-data" data-toc-modified-id="Differences-in-color-semantics-between-original-and-replication-data-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Differences in color semantics between original and replication data</a></span></li><li><span><a href="#Differences-in-color-semantics-between-self-ratings-and-other-ratings" data-toc-modified-id="Differences-in-color-semantics-between-self-ratings-and-other-ratings-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Differences in color semantics between self-ratings and other-ratings</a></span><ul class="toc-item"><li><span><a href="#Self-other-differences" data-toc-modified-id="Self-other-differences-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Self-other differences</a></span></li></ul></li></ul></li><li><span><a href="#Bonus:-color-pitch-associations-in-word-embeddings" data-toc-modified-id="Bonus:-color-pitch-associations-in-word-embeddings-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Bonus: color-pitch associations in word embeddings</a></span></li></ul></div>

# %%
# %matplotlib inline
from IPython.display import display, display_markdown

import subprocess as sp
import numpy as np
import pandas as pd
import seaborn as sns
import pymc3 as pm
import arviz as az
from bambi import Model

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 8]
plt.rcParams['figure.dpi'] = 300

from subs2vec.utensils import log_timer
from subs2vec.vecs import Vectors
from subs2vec.neighbors import compute_nn

def display_md(md, **kwargs):
    return display_markdown(md, raw=True, **kwargs)

def convert_notebook(title, output='html'):
    convert = sp.run(f'jupyter nbconvert {title}.ipynb --to {output} --output {title}.{output}'.split(' '))
    if convert.returncode == 0:
        display_md(f'Jupyter notebook `{title}` converted successfully.')
    else:
        display_md(f'Error: encountered problem converting Jupyter notebook `{title}`')

def download(fname):
    dl = sp.run(f'wget {fname}'.split(' '))
    if dl.returncode == 0:
        display_md(f'Download of `{fname}` succesful.')
    else:
        display_md(f'Download of `{fname}` failed.')

sns.set(style='whitegrid')

# %% [markdown]
# # Loading and preparing data

# %% [markdown]
# ## Loading original participant data (NZ)

# %%
df = pd.read_csv('color_semantics_ratings.tsv', sep='\t')

df = df[df['dimension'] != 'ripe-unripe']

display(df)
# Out:
#      participant  white  red  orange  yellow  green  blue  purple  brown  \
# 0              1      1    7       7       5      1     1       1      3
# 2              1      1    5       6       7      4     2       3      7
# 3              1      1    7       2       1      4     2       3      5
# 4              1      1    7       6       1      2     2       5      3
# 5              1      3    1       2       3      1     2       7      5
# ..           ...    ...  ...     ...     ...    ...   ...     ...    ...
# 539           12      1    2       1       2      2     3       2      3
# 540           12      4    3       3       4      2     2       3      2
# 541           12      2    4       2       1      2     1       2      3
# 542           12      4    2       1       1      1     3       2      3
# 543           12      6    7       4       3      4     4       1      2
#
#      black              dimension    group      pp_id
# ...

# %% [markdown]
# ### Melt dataframe to long format

# %%
colors = ['white', 'red', 'orange', 'yellow', 'green', 'blue', 'purple', 'brown', 'black']
df_orig = df.melt(
    id_vars=['group', 'dimension', 'pp_id'],
    value_vars=colors,
    var_name='color',
    value_name='rating',
)
df_orig['experiment'] = 'original'
df_orig['self_vs_other'] = 'self'

display(df_orig)
# Out:
#         group              dimension      pp_id  color  rating experiment  \
# 0     sighted               cold-hot  sighted_1  white       1   original
# 1     sighted                new-old  sighted_1  white       1   original
# 2     sighted  submissive-aggressive  sighted_1  white       1   original
# 3     sighted       selfless-jealous  sighted_1  white       1   original
# 4     sighted         active-passive  sighted_1  white       3   original
# ...       ...                    ...        ...    ...     ...        ...
# 4603    blind              soft-hard   blind_12  black       4   original
# 4604    blind            light-heavy   blind_12  black       5   original
# 4605    blind          relaxed-tense   blind_12  black       2   original
# 4606    blind             alive-dead   blind_12  black       5   original
# 4607    blind              fast-slow   blind_12  black       5   original
#
#      self_vs_other
# 0             self
# 1             self
# ...

# %% [markdown]
# ## Loading replication participant data (US)

# %%
df_rep = pd.read_csv('replication_subj_pool.csv')
df_rep = df_rep[(df_rep['pp_id'] != 3) & (df_rep['question_type'] != 'catch')]
df_rep = df_rep.drop(columns=['question_type', 'prompt_pre_1'])
df_rep = df_rep.melt(
    id_vars=['dimension', 'color', 'pp_id'],
    value_vars=['value', 'others_choice'],
    var_name='self_vs_other',
    value_name='rating',
)
df_rep['self_vs_other'] = df_rep['self_vs_other'].replace({'value': 'self', 'others_choice': 'other'})
df_rep['group'] = 'sighted'
df_rep['experiment'] = 'replication'

# there is a weird typo in one of the dimensions (?), so let's correct that here:
df_rep['dimension'] = df_rep['dimension'].replace({'like-dis...like': 'like-dislike'})

df_rep = df_rep[df_rep['dimension'] != 'ripe-unripe']

display(df_rep)
# Out:
#                   dimension   color  pp_id self_vs_other  rating    group  \
# 0               clean-dirty  yellow  69819          self       5  sighted
# 1                 soft-hard  yellow  69819          self       2  sighted
# 3          selfless-jealous  yellow  69819          self       5  sighted
# 4                  high-low  yellow  69819          self       1  sighted
# 5     submissive-aggressive  yellow  69819          self       3  sighted
# ...                     ...     ...    ...           ...     ...      ...
# 9567           like-dislike  orange  69785         other       4  sighted
# 9568                new-old  orange  69785         other       4  sighted
# 9569            clean-dirty  orange  69785         other       5  sighted
# 9570          relaxed-tense  orange  69785         other       5  sighted
# 9571         active-passive  orange  69785         other       3  sighted
#
#        experiment
# 0     replication
# 1     replication
# 3     replication
# ...

# %% [markdown]
# ## Retrieving vectors for words and dimension word pairs

# %%
# as a little bonus, add a 'high-low' dimension
dimension_labels = list(df['dimension'].unique()) + ['high-low']

dimension_pairs = [pair.split('-') for pair in dimension_labels]
from itertools import chain
dimensions = list(chain(*dimension_pairs))

# %%
# load top 200k vectors (if we load less, we miss some domain vectors)
#vecs = Vectors('../embeddings/subs.en.1e6.vec', n=2e5, d=300, normalize=True)
vecs = Vectors('../embeddings/spok.en.vec', n=1e6, d=300, normalize=True)
vecs_dict = vecs.as_dict()

from copy import deepcopy
@log_timer
def filter_vecs(vecs, filter_words):
    filtered_vecs = deepcopy(vecs)
    filtered_vecs.vectors = filtered_vecs.vectors[np.isin(filtered_vecs.words, filter_words)]
    filtered_vecs.words = filtered_vecs.words[np.isin(filtered_vecs.words, filter_words)]
    filtered_vecs.n = len(filtered_vecs.words)
    display_md(f'Filtered {vecs.n} vectors, {filtered_vecs.n} remaining.')
    return filtered_vecs

vecs = filter_vecs(vecs, np.array(colors + dimensions))
color_vecs = filter_vecs(vecs, np.array(colors))
dimension_vecs = filter_vecs(vecs, np.array(dimensions))

dimension_pair_vecs = np.vstack([vecs_dict[pair[0]] - vecs_dict[pair[1]] for pair in dimension_pairs])
# Out:
# INFO:root:loading vectors ../embeddings/spok.en.vec
# INFO:root:<function Vectors.__init__ at 0x7f8311dbed08> ran in 18.508 seconds
# INFO:root:<function Vectors.as_dict at 0x7f8311dbef28> ran in 0.169 seconds
# Filtered 234375 vectors, 43 remaining.
# INFO:root:<function filter_vecs at 0x7f83120d0488> ran in 1.069 seconds
# Filtered 43 vectors, 9 remaining.
# INFO:root:<function filter_vecs at 0x7f83120d0488> ran in 0.001 seconds
# Filtered 43 vectors, 34 remaining.
# INFO:root:<function filter_vecs at 0x7f83120d0488> ran in 0.002 seconds

# %% [markdown]
# # Finding color-semantic associations in word embeddings
# ## Using single dimension words

# %%
dimension_neighbors = compute_nn(color_vecs, dimension_vecs.vectors, dimension_vecs.words, num_neighbors=9, whole_matrix=True)
dimension_neighbors = dimension_neighbors.drop(columns=[
    'neighbor -1',
    'neighbor -2',
    'neighbor -3',
    'neighbor -4',
    'neighbor -5',
    'neighbor -6',
    'neighbor -7',
    'neighbor -8',
    'neighbor -9'
]).rename(columns={'target': 'dimension'})
display(dimension_neighbors)
# Out:
# INFO:root:<function Vectors.as_dict at 0x7f8311dbef28> ran in 0.000 seconds
# INFO:root:computing analogies using whole matrix additive method
# INFO:root:<function compute_nn at 0x7f8311dbeb70> ran in 0.005 seconds
#      dimension neighbor 0 neighbor 1 neighbor 2 neighbor 3 neighbor 4  \
# 0         like     purple     orange      green      brown     yellow
# 1          new      green     purple       blue        red      black
# 2         hard     purple      black       blue     yellow      white
# 3          old     orange        red      white     yellow      brown
# 4        happy       blue     purple      green      white      brown
# 5         high     orange     yellow      green        red      black
# 6         dead      brown      white        red      black      green
# 7        light       blue      green     orange        red      brown
# 8        angry      black      white        red      green     yellow
# ...

# %% [markdown]
# ## Using dimension axes (word pair contrasts), with nearest neighbor (cosine) method

# %%
dimension_neighbors = compute_nn(color_vecs, dimension_pair_vecs, np.array(dimension_labels), num_neighbors=9, whole_matrix=True)
dimension_neighbors = dimension_neighbors.drop(columns=[
    'neighbor -1',
    'neighbor -2',
    'neighbor -3',
    'neighbor -4',
    'neighbor -5',
    'neighbor -6',
    'neighbor -7',
    'neighbor -8',
    'neighbor -9'
]).rename(columns={'target': 'dimension'})
display(dimension_neighbors)
# Out:
# INFO:root:<function Vectors.as_dict at 0x7f8311dbef28> ran in 0.000 seconds
# INFO:root:computing analogies using whole matrix additive method
# INFO:root:<function compute_nn at 0x7f8311dbeb70> ran in 0.004 seconds
#                 dimension neighbor 0 neighbor 1 neighbor 2 neighbor 3  \
# 0                cold-hot       blue        red     orange     purple
# 1                 new-old     purple       blue      green      black
# 2   submissive-aggressive      white      black     purple      brown
# 3        selfless-jealous     purple       blue     orange      black
# 4          active-passive     orange      brown      black     yellow
# 5            like-dislike     orange      green     purple       blue
# 6             clean-dirty       blue      green     purple     orange
# 7             fresh-stale     orange      brown       blue      green
# 8              calm-angry      brown      white       blue     orange
# ...

# %% [markdown]
# It doesn't look like the high-low mapping here corresponds exactly with the one for tone and color in Saysani (2019), but maybe that is to be expected if we do not look specifically for high-_pitch_ and low-_pitch_. (But see section 4!)

# %% [markdown]
# # Predicting color semantics association ratings from word embeddings

# %% [markdown]
# ## Merging data and predictors

# %% [markdown]
# ### Merge data

# %%
df_joint = pd.concat([df_orig, df_rep])
display(df_joint)
# Out:
#         group              dimension      pp_id   color  rating   experiment  \
# 0     sighted               cold-hot  sighted_1   white       1     original
# 1     sighted                new-old  sighted_1   white       1     original
# 2     sighted  submissive-aggressive  sighted_1   white       1     original
# 3     sighted       selfless-jealous  sighted_1   white       1     original
# 4     sighted         active-passive  sighted_1   white       3     original
# ...       ...                    ...        ...     ...     ...          ...
# 9567  sighted           like-dislike      69785  orange       4  replication
# 9568  sighted                new-old      69785  orange       4  replication
# 9569  sighted            clean-dirty      69785  orange       5  replication
# 9570  sighted          relaxed-tense      69785  orange       5  replication
# 9571  sighted         active-passive      69785  orange       3  replication
#
#      self_vs_other
# 0             self
# ...

# %% [markdown]
# ### Add word frequency (Van Paridon & Thompson, 2020)

# %%
freqs = pd.read_csv('../embeddings/dedup.en.words.unigrams.tsv', sep='\t')
freqs['log_freq'] = np.log(freqs['unigram_freq'])
freqs = freqs.drop(columns='unigram_freq')
display(freqs.round(2))
# Out:
#             unigram  log_freq
# 0               the     17.10
# 1               you     17.06
# 2                 i     17.04
# 3                to     16.78
# 4                 a     16.59
# ...             ...       ...
# 2397976       tpar1      0.00
# 2397977     giacoia      0.00
# 2397978  ourcinders      0.00
# 2397979     tourret      0.00
# 2397980       iroki      0.00
#
# [2397981 rows x 2 columns]

# %%
df_joint['word1'] = df_joint['dimension'].apply(lambda x: x.split('-')[0])
df_joint['word2'] = df_joint['dimension'].apply(lambda x: x.split('-')[1])
df_joint = df_joint.merge(freqs, left_on='word1', right_on='unigram', how='left')
df_joint = df_joint.merge(freqs, left_on='word2', right_on='unigram', how='left')
df_joint['frequency'] = df_joint['log_freq_x'] - df_joint['log_freq_y']
df_joint = df_joint.drop(columns=[
    'unigram_x',
    'unigram_y',
    'log_freq_x',
    'log_freq_y'
])
display(df_joint.round(2))
# Out:
#          group              dimension      pp_id   color  rating   experiment  \
# 0      sighted               cold-hot  sighted_1   white       1     original
# 1      sighted                new-old  sighted_1   white       1     original
# 2      sighted  submissive-aggressive  sighted_1   white       1     original
# 3      sighted       selfless-jealous  sighted_1   white       1     original
# 4      sighted         active-passive  sighted_1   white       3     original
# ...        ...                    ...        ...     ...     ...          ...
# 13647  sighted           like-dislike      69785  orange       4  replication
# 13648  sighted                new-old      69785  orange       4  replication
# 13649  sighted            clean-dirty      69785  orange       5  replication
# 13650  sighted          relaxed-tense      69785  orange       5  replication
# 13651  sighted         active-passive      69785  orange       3  replication
#
# ...

# %% [markdown]
# ### Add concreteness (Brysbaert et al., 2014)

# %%
concreteness = pd.read_csv('../embeddings/en-brysbaert-2014.tsv', sep='\t')
display(concreteness)
# Out:
#             word  concreteness
# 0              a          1.46
# 1       aardvark          4.68
# 2          aback          1.65
# 3         abacus          4.52
# 4        abandon          2.54
# ...          ...           ...
# 37053  zoologist          4.30
# 37054    zoology          3.37
# 37055       zoom          3.10
# 37056  zoophobia          2.04
# 37057   zucchini          4.87
#
# [37058 rows x 2 columns]

# %%
df_joint = df_joint.merge(concreteness, left_on='word1', right_on='word', how='left')
df_joint = df_joint.merge(concreteness, left_on='word2', right_on='word', how='left')
df_joint['concreteness'] = df_joint['concreteness_x'] - df_joint['concreteness_y']
df_joint = df_joint.drop(columns=[
    'word_x',
    'word_y',
    'concreteness_x',
    'concreteness_y'
])
display(df_joint.round(2))
# Out:
#          group              dimension      pp_id   color  rating   experiment  \
# 0      sighted               cold-hot  sighted_1   white       1     original
# 1      sighted                new-old  sighted_1   white       1     original
# 2      sighted  submissive-aggressive  sighted_1   white       1     original
# 3      sighted       selfless-jealous  sighted_1   white       1     original
# 4      sighted         active-passive  sighted_1   white       3     original
# ...        ...                    ...        ...     ...     ...          ...
# 13647  sighted           like-dislike      69785  orange       4  replication
# 13648  sighted                new-old      69785  orange       4  replication
# 13649  sighted            clean-dirty      69785  orange       5  replication
# 13650  sighted          relaxed-tense      69785  orange       5  replication
# 13651  sighted         active-passive      69785  orange       3  replication
#
# ...

# %% [markdown]
# ### Add Small World of Words associations (De Deyne et al., 2018)

# %%
swow = pd.read_csv('../embeddings/SWOW-EN.R100.csv')
#swow = swow[(swow['country'] == 'New Zealand') | (swow['country'] == 'Australia')]
#swow = swow[(swow['country'] == 'United States')]
swow = swow[swow['cue'].isin(dimensions)]

# count only R1 (maximal discounting)
swow_R1 = pd.DataFrame(swow.groupby('cue')['R1'].value_counts()).rename(columns={'R1': 'n'})
swow_R1 = swow_R1.reset_index().rename(columns={'R1': 'resp'})
display(swow_R1)

# count R1, R2, and R3 with equal weight (minimal discounting)
swow_all = swow.melt(
    id_vars=['id', 'participantID', 'created_at', 'cue'],
    value_vars=['R1', 'R2', 'R3'],
    value_name='resp',
)
swow_all = pd.DataFrame(swow_all.groupby('cue')['resp'].value_counts()).rename(columns={'resp': 'n'})
swow_all = swow_all.reset_index()
display(swow_all)
# Out:
#          cue       resp  n
# 0     active    passive  9
# 1     active  energetic  7
# 2     active        fit  6
# 3     active     moving  6
# 4     active   exercise  5
# ...      ...        ... ..
# 1459   tense     taught  1
# 1460   tense       taut  1
# 1461   tense    tension  1
# 1462   tense         up  1
# 1463   tense       word  1
#
# [1464 rows x 3 columns]
#          cue       resp   n
# 0     active   exercise  17
# 1     active  energetic  16
# 2     active    passive  16
# 3     active     moving  15
# 4     active       busy  10
# ...      ...        ...  ..
# 4291   tense      upset   1
# 4292   tense       wire   1
# 4293   tense      wired   1
# 4294   tense       work   1
# 4295   tense      worry   1
#
# [4296 rows x 3 columns]

# %%
df_joint = df_joint.merge(swow_all, left_on=['word1', 'color'], right_on=['cue', 'resp'], how='left').fillna(0)
df_joint = df_joint.merge(swow_all, left_on=['word2', 'color'], right_on=['cue', 'resp'], how='left').fillna(0)
df_joint['swow_n'] = df_joint['n_x'] - df_joint['n_y']
df_joint = df_joint.drop(columns=[
    'cue_x',
    'cue_y',
    'resp_x',
    'resp_y',
    'n_x',
    'n_y',
])
display(df_joint)
# Out:
#          group              dimension      pp_id   color  rating   experiment  \
# 0      sighted               cold-hot  sighted_1   white       1     original
# 1      sighted                new-old  sighted_1   white       1     original
# 2      sighted  submissive-aggressive  sighted_1   white       1     original
# 3      sighted       selfless-jealous  sighted_1   white       1     original
# 4      sighted         active-passive  sighted_1   white       3     original
# ...        ...                    ...        ...     ...     ...          ...
# 13647  sighted           like-dislike      69785  orange       4  replication
# 13648  sighted                new-old      69785  orange       4  replication
# 13649  sighted            clean-dirty      69785  orange       5  replication
# 13650  sighted          relaxed-tense      69785  orange       5  replication
# 13651  sighted         active-passive      69785  orange       3  replication
#
# ...

# %% [markdown]
# ### Add cosine distance (Mikolov et al., 2013)

# %%
def norm(x):
    return x / np.linalg.norm(x, 2)
    
df_joint['cosine_spok'] = df_joint.apply(
    lambda x: np.dot(norm(vecs_dict[x['word1']] - vecs_dict[x['word2']]), vecs_dict[x['color']]), axis=1
)
display(df_joint.round(2))
# Out:
#          group              dimension      pp_id   color  rating   experiment  \
# 0      sighted               cold-hot  sighted_1   white       1     original
# 1      sighted                new-old  sighted_1   white       1     original
# 2      sighted  submissive-aggressive  sighted_1   white       1     original
# 3      sighted       selfless-jealous  sighted_1   white       1     original
# 4      sighted         active-passive  sighted_1   white       3     original
# ...        ...                    ...        ...     ...     ...          ...
# 13647  sighted           like-dislike      69785  orange       4  replication
# 13648  sighted                new-old      69785  orange       4  replication
# 13649  sighted            clean-dirty      69785  orange       5  replication
# 13650  sighted          relaxed-tense      69785  orange       5  replication
# 13651  sighted         active-passive      69785  orange       3  replication
#
# ...

# %%
fic_vecs = Vectors('../embeddings/fic.en.vec', n=2e5, d=300, normalize=True)
fic_vecs_dict = fic_vecs.as_dict()

df_joint['cosine_fic'] = df_joint.apply(
    lambda x: np.dot(norm(fic_vecs_dict[x['word1']] - fic_vecs_dict[x['word2']]), fic_vecs_dict[x['color']]), axis=1
)
display(df_joint.round(2))
# Out:
# INFO:root:loading vectors ../embeddings/fic.en.vec
# INFO:root:<function Vectors.__init__ at 0x7f8311dbed08> ran in 16.295 seconds
# INFO:root:<function Vectors.as_dict at 0x7f8311dbef28> ran in 0.140 seconds
#          group              dimension      pp_id   color  rating   experiment  \
# 0      sighted               cold-hot  sighted_1   white       1     original
# 1      sighted                new-old  sighted_1   white       1     original
# 2      sighted  submissive-aggressive  sighted_1   white       1     original
# 3      sighted       selfless-jealous  sighted_1   white       1     original
# 4      sighted         active-passive  sighted_1   white       3     original
# ...        ...                    ...        ...     ...     ...          ...
# 13647  sighted           like-dislike      69785  orange       4  replication
# 13648  sighted                new-old      69785  orange       4  replication
# ...

# %% [markdown]
# ### Standardize predictors and plot correlations

# %%
def standardize(Series):
    return (Series - Series.mean()) / Series.std()

#df_joint = df_joint[df_joint['experiment'] == 'original']

df_joint['rating_z'] = standardize(df_joint['rating'])
df_joint['frequency_z'] = standardize(df_joint['frequency'])
df_joint['concreteness_z'] = standardize(df_joint['concreteness'])
df_joint['swow_n_z'] = standardize(df_joint['swow_n'])

df_joint['cosine_spok_z'] = standardize(df_joint['cosine_spok'])
df_joint['cosine_fic_z'] = standardize(df_joint['cosine_fic'])

df_joint['blind'] = pd.get_dummies(df_joint['group'])['blind']
df_joint['sighted'] = pd.get_dummies(df_joint['group'])['sighted']
df_joint['group_bin'] = (df_joint['sighted'] - .5) * 2
df_joint['group_z'] = standardize(df_joint['sighted'])

df_joint['original'] = pd.get_dummies(df_joint['experiment'])['original']
df_joint['replication'] = pd.get_dummies(df_joint['experiment'])['replication']
df_joint['experiment_bin'] = (df_joint['replication'] - .5) * 2
df_joint['experiment_z'] = standardize(df_joint['replication'])

df_joint['other'] = pd.get_dummies(df_joint['self_vs_other'])['other']
df_joint['self_vs_other_z'] = (df_joint['other'] - .5) * 2

display(df_joint)
# Out:
#          group              dimension      pp_id   color  rating   experiment  \
# 0      sighted               cold-hot  sighted_1   white       1     original
# 1      sighted                new-old  sighted_1   white       1     original
# 2      sighted  submissive-aggressive  sighted_1   white       1     original
# 3      sighted       selfless-jealous  sighted_1   white       1     original
# 4      sighted         active-passive  sighted_1   white       3     original
# ...        ...                    ...        ...     ...     ...          ...
# 13647  sighted           like-dislike      69785  orange       4  replication
# 13648  sighted                new-old      69785  orange       4  replication
# 13649  sighted            clean-dirty      69785  orange       5  replication
# 13650  sighted          relaxed-tense      69785  orange       5  replication
# 13651  sighted         active-passive      69785  orange       3  replication
#
# ...

# %%
df_joint.to_csv('fic_vs_spok_data.tsv', sep='\t')

# %%
corrs = np.abs(df_joint[[
    'rating',
    'cosine_spok',
    'cosine_fic',
    'swow_n',
    'frequency',
    'concreteness',
]].corr()).round(2)
g = sns.heatmap(corrs, vmin=0, vmax=1, annot=True)

# %%
m_dummy = Model(df_joint[df_joint['experiment'] == 'original'])
r_dummy = m_dummy.fit(
    'rating_z ~ 1'
    + ' + sighted*frequency_z'
    + ' + sighted*concreteness_z'
    + ' + sighted*cosine_fic_z'
    + ' + sighted*swow_n_z',
    random=[
        #'1|pp_id',
        #'1|dimension',
        #'1|color',
    ],
    init='advi+adapt_diag',
    chains=3,
    samples=2000,
    tune=2000,
    target_accept=.9,
)

# %%
m_bin = Model(df_joint[df_joint['experiment'] == 'original'])
r_bin = m_bin.fit(
    'rating_z ~ 1'
    + ' + group_bin*frequency_z'
    + ' + group_bin*concreteness_z'
    + ' + group_bin*cosine_fic_z'
    + ' + group_bin*swow_n_z',
    random=[
        #'1|pp_id',
        #'1|dimension',
        #'1|color',
    ],
    init='advi+adapt_diag',
    chains=3,
    samples=2000,
    tune=2000,
    target_accept=.9,
)
# Out:
# Auto-assigning NUTS sampler...
# INFO:pymc3:Auto-assigning NUTS sampler...
# Initializing NUTS using advi+adapt_diag...
# INFO:pymc3:Initializing NUTS using advi+adapt_diag...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='22066' class='' max='50000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       44.13% [22066/50000 00:14<00:18 Average Loss = 6,385.4]
#     </div>
# Convergence achieved at 22300
# ...

# %%
m_z = Model(df_joint[df_joint['experiment'] == 'original'])
r_z = m_z.fit(
    'rating_z ~ 1'
    + ' + group_z*frequency_z'
    + ' + group_z*concreteness_z'
    + ' + group_z*cosine_fic_z'
    + ' + group_z*swow_n_z',
    random=[
        #'1|pp_id',
        #'1|dimension',
        #'1|color',
    ],
    init='advi+adapt_diag',
    chains=3,
    samples=2000,
    tune=2000,
    target_accept=.9,
)
# Out:
# Auto-assigning NUTS sampler...
# INFO:pymc3:Auto-assigning NUTS sampler...
# Initializing NUTS using advi+adapt_diag...
# INFO:pymc3:Initializing NUTS using advi+adapt_diag...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21656' class='' max='50000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       43.31% [21656/50000 00:14<00:18 Average Loss = 6,385.2]
#     </div>
# Convergence achieved at 21900
# ...

# %%
# compute and plot conditional effect of cosine in sighted and blind groups
from copy import deepcopy
trace_orig = deepcopy(m_dummy.backend.trace)
trace_orig.add_values({
    'blind:cosine_fic_z': trace_orig['cosine_fic_z'],
    'sighted_:cosine_fic_z': trace_orig['cosine_fic_z'] + trace_orig['sighted:cosine_fic_z'],
})

varnames = ['blind:cosine_fic_z', 'sighted_:cosine_fic_z']
g = az.plot_forest(trace_orig, combined=True, hdi_prob=.95,
                   figsize=[9, .6 + len(varnames) * .3],
                   var_names=varnames)
g[0].axvline(0, color='.8', linewidth=2);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/arviz/data/io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,

# %%
# compute and plot conditional effect of cosine in sighted and blind groups
from copy import deepcopy
trace_orig = deepcopy(m_bin.backend.trace)
trace_orig.add_values({
    'blind:cosine_fic_z': trace_orig['cosine_fic_z'] - trace_orig['group_bin:cosine_fic_z'],
    'sighted:cosine_fic_z': trace_orig['cosine_fic_z'] + trace_orig['group_bin:cosine_fic_z']
})

varnames = ['cosine_fic_z', 'blind:cosine_fic_z', 'sighted:cosine_fic_z']
g = az.plot_forest(trace_orig, combined=True, hdi_prob=.95,
                   figsize=[9, .6 + len(varnames) * .3],
                   var_names=varnames)
g[0].axvline(0, color='.8', linewidth=2);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/arviz/data/io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,

# %%
# compute and plot conditional effect of cosine in sighted and blind groups
from copy import deepcopy
trace_orig = deepcopy(m_z.backend.trace)
trace_orig.add_values({
    'blind:cosine_fic_z': trace_orig['cosine_fic_z'] - trace_orig['group_z:cosine_fic_z'],
    'sighted:cosine_fic_z': trace_orig['cosine_fic_z'] + trace_orig['group_z:cosine_fic_z']
})

varnames = ['cosine_fic_z', 'blind:cosine_fic_z', 'sighted:cosine_fic_z']
g = az.plot_forest(trace_orig, combined=True, hdi_prob=.95,
                   figsize=[9, .6 + len(varnames) * .3],
                   var_names=varnames)
g[0].axvline(0, color='.8', linewidth=2);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/arviz/data/io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,

# %% [markdown]
# ## Predicting color semantics in original data (blind vs. sighted in NZ)

# %%
m_original_fe = Model(df_joint[df_joint['experiment'] == 'original'])
r_original_fe = m_original_fe.fit(
    'rating_z ~ 1'
    + ' + group_z*frequency_z'
    + ' + group_z*concreteness_z'
    + ' + group_z*cosine_spok_z*cosine_fic_z'
    + ' + group_z*swow_n_z',
    random=[
        '1|pp_id',
        '1|dimension',
        '1|color',
    ],
    init='advi+adapt_diag',
    chains=3,
    samples=1000,
    tune=1000,
    target_accept=.9,
)
# Out:
# Auto-assigning NUTS sampler...
# INFO:pymc3:Auto-assigning NUTS sampler...
# Initializing NUTS using advi+adapt_diag...
# INFO:pymc3:Initializing NUTS using advi+adapt_diag...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='27454' class='' max='50000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       54.91% [27454/50000 00:32<00:26 Average Loss = 6,350.2]
#     </div>
# Convergence achieved at 27500
# ...

# %%
varnames = [
    'Intercept',
    'group_z',
    'frequency_z',
    'concreteness_z',
    'cosine_spok_z',
    'cosine_fic_z',
    'swow_n_z',
    'group_z:frequency_z',
    'group_z:concreteness_z',
    'group_z:cosine_spok_z',
    'group_z:cosine_fic_z',
    'cosine_spok_z:cosine_fic_z',
    'group_z:cosine_spok_z:cosine_fic_z',
    'group_z:swow_n_z',
]
g = az.plot_forest(r_original_fe, combined=True, hdi_prob=.95,
                   figsize=[9, .6 + len(varnames) * .3],
                   var_names=varnames)
g[0].axvline(0, color='.8', linewidth=2);

# %%
varnames = [
    'Intercept',
    'group_z',
    'frequency_z',
    'concreteness_z',
    'cosine_spok_z',
    'cosine_fic_z',
    'swow_n_z',
    'group_z:frequency_z',
    'group_z:concreteness_z',
    'group_z:cosine_spok_z',
    'group_z:cosine_fic_z',
    'cosine_spok_z:cosine_fic_z',
    'group_z:cosine_spok_z:cosine_fic_z',
    'group_z:swow_n_z',
]
g = az.plot_forest(r_original_fe, combined=True, hdi_prob=.95,
                   figsize=[9, .6 + len(varnames) * .3],
                   var_names=varnames)
g[0].axvline(0, color='.8', linewidth=2);

# %%
m_original = Model(df_joint[df_joint['experiment'] == 'original'])
r_original = m_original.fit(
    'rating_z ~ 1'
    + ' + group_z*frequency_z'
    + ' + group_z*concreteness_z'
    + ' + group_z*cosine_spok_z*cosine_fic_z'
    + ' + group_z*swow_n_z',
    random=[
        '1 + frequency_z + concreteness_z + cosine_spok_z*cosine_fic_z + swow_n_z + color + dimension|pp_id',
        '1 + group_z|dimension',
        '1 + group_z|color',
    ],
    init='advi+adapt_diag',
    chains=3,
    samples=2000,
    tune=2000,
    #target_accept=.9,
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/bambi/models.py:572: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   pred_data = pred_data[:, None]  # Must be 2D later
# ...

# %%
varnames = [
    'Intercept',
    'group_z',
    'frequency_z',
    'concreteness_z',
    'cosine_spok_z',
    'cosine_fic_z',
    'swow_n_z',
    'group_z:frequency_z',
    'group_z:concreteness_z',
    'group_z:cosine_spok_z',
    'group_z:cosine_fic_z',
    'cosine_spok_z:cosine_fic_z',
    'group_z:cosine_spok_z:cosine_fic_z',
    'group_z:swow_n_z',
]
g = az.plot_forest(r_original, combined=True, hdi_prob=.95,
                   figsize=[9, .6 + len(varnames) * .3],
                   var_names=varnames)
g[0].axvline(0, color='.8', linewidth=2);

# %% [markdown]
# In the original experiment, the main effects of cosine and SWOW look pretty robust.
#
# There is no difference in the effect of SWOW between the sighted and blind participants, but there is a non-zero group:cosine interaction, meaning that word embeddings are more predictive of sighted participants' ratings than of blind participants' ratings. In fact, if we compute the conditional effect of cosine in each of the groups (which we can do post-hoc, see figure below) it seems that in the blind group the effect of cosine might well be zero.

# %%
# compute and plot conditional effect of cosine in sighted and blind groups
from copy import deepcopy
trace_orig = deepcopy(m_original.backend.trace)
trace_orig.add_values({
    'blind:cosine_spok_z': trace_orig['cosine_spok_z'] - trace_orig['group_z:cosine_spok_z'],
    'sighted:cosine_spok_z': trace_orig['cosine_spok_z'] + trace_orig['group_z:cosine_spok_z'],
    'blind:cosine_fic_z': trace_orig['cosine_fic_z'] - trace_orig['group_z:cosine_fic_z'],
    'sighted:cosine_fic_z': trace_orig['cosine_fic_z'] + trace_orig['group_z:cosine_fic_z']
})

varnames = ['blind:cosine_spok_z', 'sighted:cosine_spok_z', 'blind:cosine_fic_z', 'sighted:cosine_fic_z']
g = az.plot_forest(trace_orig, combined=True, hdi_prob=.95,
                   figsize=[9, .6 + len(varnames) * .3],
                   var_names=varnames)
g[0].axvline(0, color='.8', linewidth=2);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/arviz/data/io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,

# %% [markdown]
# ## Predicting color semantics in replication data (sighted in US)

# %%
m_replication = Model(df_joint[(df_joint['experiment'] == 'replication') & (df_joint['self_vs_other'] == 'self')])
r_replication = m_replication.fit(
    'rating_z ~ 1'
    + ' + frequency_z'
    + ' + concreteness_z'
    + ' + cosine_spok_z*cosine_fic_z'
    + ' + swow_n_z',
    random=[
        '1 + frequency_z + concreteness_z + cosine_spok_z*cosine_fic_z + swow_n_z + color + dimension|pp_id',
        '1|dimension',
        '1|color',
    ],
    init='advi+adapt_diag',
    chains=3,
    samples=2000,
    tune=2000,
    target_accept=.9,
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/bambi/models.py:572: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   pred_data = pred_data[:, None]  # Must be 2D later
# Auto-assigning NUTS sampler...
# INFO:pymc3:Auto-assigning NUTS sampler...
# Initializing NUTS using advi+adapt_diag...
# INFO:pymc3:Initializing NUTS using advi+adapt_diag...
#     <div>
#         <style>
# ...

# %%
varnames = [
    'Intercept',
    'frequency_z',
    'concreteness_z',
    'cosine_spok_z',
    'cosine_fic_z',
    'cosine_spok_z:cosine_fic_z',
    'swow_n_z',
]
g = az.plot_forest(r_replication, combined=True, hdi_prob=.95,
                   figsize=[9, .6 + len(varnames) * .3],
                   var_names=varnames)
g[0].axvline(0, color='.8', linewidth=2);

# %% [markdown]
# In the replication model we see a fairly robust effect of cosine and a slightly smaller effect of SWOW. These observations findings are broadly consistent with what we see in the sighted group in the original experiment.

# %% [markdown]
# ## Differences in color semantics between original and replication data

# %%
m_orig_vs_rep = Model(df_joint[df_joint['self_vs_other'] == 'self'])
r_orig_vs_rep = m_orig_vs_rep.fit(
    'rating_z ~ 1'
    + ' + group_z*frequency_z'
    + ' + group_z*concreteness_z'
    + ' + group_z*cosine_spok_z*cosine_fic_z'
    + ' + group_z*swow_n_z'
    + ' + experiment_z*frequency_z'
    + ' + experiment_z*concreteness_z'
    + ' + experiment_z*cosine_spok_z*cosine_fic_z'
    + ' + experiment_z*swow_n_z',
    random=[
        '1 + frequency_z + concreteness_z + cosine_spok_z*cosine_fic_z + swow_n_z + color + dimension|pp_id',
        '1 + experiment_z + group_z|dimension',
        '1 + experiment_z + group_z|color',
    ],
    init='advi+adapt_diag',
    chains=3,
    samples=1000,
    tune=1000,
    target_accept=.9,
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/bambi/models.py:572: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   pred_data = pred_data[:, None]  # Must be 2D later
# ...

# %%
varnames = [
    'Intercept',
    'group_z',
    'experiment_z',
    'frequency_z',
    'concreteness_z',
    'cosine_spok_z',
    'cosine_fic_z',
    'cosine_spok_z:cosine_fic_z',
    'swow_n_z',
    'group_z:frequency_z',
    'group_z:concreteness_z',
    'group_z:cosine_spok_z',
    'group_z:cosine_fic_z',
    'group_z:cosine_spok_z:cosine_fic_z',
    'group_z:swow_n_z',
    'experiment_z:frequency_z',
    'experiment_z:concreteness_z',
    'experiment_z:cosine_spok_z',
    'experiment_z:cosine_fic_z',
    'experiment_z:cosine_spok_z:cosine_fic_z',
    'experiment_z:swow_n_z',
]
g = az.plot_forest(r_orig_vs_rep, combined=True, hdi_prob=.95,
                   figsize=[9, .6 + len(varnames) * .3],
                   var_names=varnames)
g[0].axvline(0, color='.8', linewidth=2);

# %% [markdown]
# When pooling the original and replication experiments into a single model, the main effects of cosine and SWOW look fairly robust.
#
# This pooled model also shows the group:cosine interaction, meaning that word embeddings are _more_ predictive of sighted participants' ratings than of blind participants' ratings. If we compute the conditional effect of cosine in each of the groups (which we can do post-hoc, see figure below) like we did when modelling the original experiment, it seems that in the blind group the effect of cosine is highly uncertain and quite possibly zero.
#
# The effect of SWOW is similar in direction to what we see when we model the original and replication experiments separately, but there is a small experiment:swow interaction effect, meaning SWOW is more predictive of ratings in sighted participants in the NZ sample than in the US sample. It's hard to say what the origin of this effect would be, because the NZ participants' linguistic associations stem from a smaller and more isolated language community, which one might expect to cause them to be _more_ different from the SWOW associations rather than _less_ different. (This is pretty speculative, though.)

# %%
# compute and plot conditional effect of cosine in sighted and blind groups
from copy import deepcopy
trace_vs = deepcopy(m_orig_vs_rep.backend.trace)
trace_vs.add_values({
    # effect of cosine in blind group in orginal experiment
    'blind:cosine_z': trace_vs['cosine_z'] - trace_vs['group_z:cosine_z'] - trace_vs['experiment_z:cosine_z'],
    # effect of cosine in sighted group across both experiments
    'sighted:cosine_z': trace_vs['cosine_z'] + trace_vs['group_z:cosine_z'],
})

varnames = ['blind:cosine_z', 'sighted:cosine_z']
g = az.plot_forest(trace_vs, combined=True, hdi_prob=.95,
                   figsize=[9, .6 + len(varnames) * .3],
                   var_names=varnames)
g[0].axvline(0, color='.8', linewidth=2);

# %% [markdown]
# ## Differences in color semantics between self-ratings and other-ratings

# %%
m_self_vs_other = Model(df_joint[df_joint['experiment'] == 'replication'])
r_self_vs_other = m_self_vs_other.fit(
    'rating_z ~ 1'
    + ' + self_vs_other_z*frequency_z'
    + ' + self_vs_other_z*concreteness_z'
    + ' + self_vs_other_z*cosine_z'
    + ' + self_vs_other_z*swow_n_z',
    random=[
        '1 + frequency_z + concreteness_z + cosine_z + swow_n_z + color + dimension|pp_id',
        '1 + self_vs_other_z|dimension',
        '1 + self_vs_other_z|color',
    ],
    init='advi+adapt_diag',
    chains=3,
    samples=2000,
    tune=2000,
    target_accept=.9,
)

# %%
varnames = [
    'Intercept',
    'self_vs_other_z',
    'frequency_z',
    'concreteness_z',
    'cosine_z',
    'swow_n_z',
    'self_vs_other_z:frequency_z',
    'self_vs_other_z:concreteness_z',
    'self_vs_other_z:cosine_z',
    'self_vs_other_z:swow_n_z',
]
g = az.plot_forest(r_self_vs_other, combined=True, hdi_prob=.95,
                   figsize=[9, .6 + len(varnames) * .3],
                   var_names=varnames)
g[0].axvline(0, color='.8', linewidth=2);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-34939e0682b3> in <module>
#      11     'self_vs_other_z:swow_n_z',
#      12 ]
# ---> 13 g = az.plot_forest(r_self_vs_other, combined=True, hdi_prob=.95,
#      14                    figsize=[9, .6 + len(varnames) * .3],
#      15                    var_names=varnames)
#
# NameError: name 'r_self_vs_other' is not defined

# %% [markdown]
# There appears to be no discernable difference between self- and other-ratings in the replication experiment.

# %% [markdown]
# ### Self-other differences

# %%
df_self = df_joint[(df_joint['experiment'] == 'replication') & (df_joint['self_vs_other'] == 'self')].sort_values(['pp_id', 'dimension', 'color'])
df_other = df_joint[df_joint['self_vs_other'] == 'other'].sort_values(['pp_id', 'dimension', 'color'])

df_self['rating_diff'] = np.abs(df_self['rating'].values - df_other['rating'].values)
df_self['rating_diff_z'] = standardize(df_self['rating_diff'])

# %%
m_diff = Model(df_self)
r_diff = m_diff.fit(
    'rating_diff_z ~ 1'
    + ' + frequency_z'
    + ' + concreteness_z'
    + ' + cosine_z'
    + ' + swow_n_z',
    random=[
        '1 + frequency_z + concreteness_z + cosine_z + swow_n_z + color + dimension|pp_id',
        '1|dimension',
        '1|color',
    ],
    init='advi+adapt_diag',
    chains=3,
    samples=2000,
    tune=2000,
    target_accept=.9,
)

# %%
varnames = [
    'Intercept',
    'frequency_z',
    'concreteness_z',
    'cosine_z',
    'swow_n_z',
]
g = az.plot_forest(r_diff, combined=True, hdi_prob=.95,
                   figsize=[9, .6 + len(varnames) * .3],
                   var_names=varnames)
g[0].axvline(0, color='.8', linewidth=2);

# %% [markdown]
# Differences between self- and other-ratings are apparently not related to anything.

# %% [markdown]
# # Bonus: color-pitch associations in word embeddings

# %%
# load vectors
linked_vecs = Vectors('../embeddings/linked.mega.en.1e6.vec', n=2e5, d=300, normalize=True)
linked_vecs_dict = linked_vecs.as_dict()

# %%
y = [np.dot(norm(linked_vecs_dict['low_pitch'] - linked_vecs_dict['high_pitch']),
            linked_vecs_dict[color]) for color in colors]
df_pitch = pd.DataFrame(zip(colors, y), columns=['color', 'pitch'])
display(df_pitch)

# %%
g = sns.catplot(x='color', y='pitch', color='black', data=df_pitch.sort_values('pitch'), height=6)
